# %% [markdown]
# ### Live Crypto Price Tracker with Refreshing Chart

# %%
# 0. import 
import requests
import

# %%
# 1. set constants
# "BTCUSDT"         # Bitcoin vs USD
            # seconds between updates
            # list to hold (time, price)

# %%
# 2. run while loop forever

    
    # 4. fetch current price (Binance public API)
    # "https://api.binance.us/api/v3/ticker/price?symbol="
    
    # 5. floatify price

    
    # 6. get datetime


    # 27. store new record to history list as dict


    # 8. turn into DataFrame for plotting


    # 9. clear and redraw plot (line chart)
    
    # 10. print and pause
